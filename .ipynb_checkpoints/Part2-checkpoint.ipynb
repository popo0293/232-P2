# %% [markdown]
# #### Question 18

# %%
library(igraph)
library(corrplot)

egoNodes <- dir("gplus",pattern = "circles")
print(paste("There are ", length(egoNodes), " personal networks in total."))
# Out:
# [1] "There are  132  personal networks in total."

# %% [markdown]
# #### Question 19

# %%
el <- matrix( c("foo", "bar", "bar", "foobar"), nc = 2, byrow = TRUE)
gg <- graph_from_edgelist(el)
plot(gg,vertex.size=4, vertex.label.cex=0.3)
# Out:
# Plot with title ""

# %%
edge_list[1,1]
# Out:
# [1] 1.160966e+20

# %%
node2plot <- c("109327480479767108490", 
               "115625564993990145546", 
               "101373961279443806744")

for (id in node2plot)
{
    file2plot <- paste("gplus/", id, sep="")
    edge_file <- paste(file2plot, ".edges", sep="")
    edge_list <- scan(edge_file, what=numeric())
    edge_list <- matrix(as.numeric(factor(edge_list)), nc = 2, byrow = TRUE)
    g = graph_from_edgelist(edge_list)
    plot(g, vertex.size=4, vertex.label.cex=0.3)
}

# %%
general_filenames <- list()
for (i in 1:length(egoNodes))
{
  general_filenames[[i]] <- strsplit(egoNodes[i],".circles")
  circles_file <- paste("gplus/", general_filenames[[i]], ".circles", sep="")
  file_connection <- file(circles_file , open="r")
  circles <- readLines(file_connection)
  close(file_connection)
  
  # check if more than 2 circles
  if(length(circles) > 2)
  {
    all_circles <- list()
    for (c in 1:length(circles)) 
    {
      content <- strsplit(circles[c],"\t")
      all_circles <- c(all_circles, list(content[[1]][-1]))
    }
  
    edges_file <- paste("gplus/", general_filenames[[i]], ".edges", sep="")
    google_network <- read.graph(edges_file, format = "ncol", directed=TRUE)
    google_network <- add.vertices(google_network, nv = 1, name = general_filenames[[i]])
    
    edge_list <- c()
    for (node in 1:(vcount(google_network)-1))
    {
      edge_list <- c(edge_list, c(vcount(google_network), node))
    }
    
    google_network <- add_edges(google_network, edge_list)
    
    info_map_community <- infomap.community(google_network)
    walk_trap_community <- walktrap.community(google_network)
    
    info_map_overlap_ratio <- vector()
    walk_trap_overlap_ratio <- vector()
    for(x in 1:max(info_map_community$membership))
    {
      info_map_community_nodes = V(google_network)$name[which(info_map_community$membership == x)]
      
      for (c in 1:length(all_circles))
      {
        union_nodes <- length(union(info_map_community_nodes, all_circles[[c]]))
        info_map_overlap_ratio = c(info_map_overlap_ratio, length(intersect(info_map_community_nodes, all_circles[[c]]))/union_nodes)
      }
    }
    
    for(x in 1:max(walk_trap_community$membership))
    {
      walk_trap_community_nodes = V(google_network)$name[which(walk_trap_community$membership == x)]
      
      for (c in 1:length(all_circles))
      {
        union_nodes <- length(union(walk_trap_community_nodes, all_circles[[c]]))
        walk_trap_overlap_ratio = c(walk_trap_overlap_ratio, length(intersect(walk_trap_community_nodes, all_circles[[c]]))/union_nodes)
      }
    }

    print(paste("Number of circles = ", length(all_circles)))
    print(paste("Walktrap ratio (MAX) =  ",max(walk_trap_overlap_ratio)))
    print(paste("Walktrap ratio (AVG) =  ",mean(walk_trap_overlap_ratio)))
    print(paste("Infomap ratio (MAX) = ",max(info_map_overlap_ratio)))
    print(paste("Infomap ratio (AVG) = ",mean(info_map_overlap_ratio)))
  
  }
}
# Out:
# [1] "Number of circles =  4"
# [1] "Walktrap ratio (MAX) =   0.529331514324693"
# [1] "Walktrap ratio (AVG) =   0.0826457723531556"
# [1] "Infomap ratio (MAX) =  0.43677130044843"
# [1] "Infomap ratio (AVG) =  0.0140909714519929"
# [1] "Number of circles =  3"
# [1] "Walktrap ratio (MAX) =   0.677710843373494"
# [1] "Walktrap ratio (AVG) =   0.100678018021018"
# [1] "Infomap ratio (MAX) =  0.459302325581395"
# [1] "Infomap ratio (AVG) =  0.0386222090734326"
# [1] "Number of circles =  4"
# [1] "Walktrap ratio (MAX) =   0.0763358778625954"
# [1] "Walktrap ratio (AVG) =   0.00211326088720709"
# [1] "Infomap ratio (MAX) =  0.105304518664047"
# [1] "Infomap ratio (AVG) =  0.00454322200392927"
# [1] "Number of circles =  3"
# [1] "Walktrap ratio (MAX) =   0.212121212121212"
# [1] "Walktrap ratio (AVG) =   0.0378792205075374"
# [1] "Infomap ratio (MAX) =  0.321100917431193"
# [1] "Infomap ratio (AVG) =  0.0139666796386896"
# [1] "Number of circles =  4"
# [1] "Walktrap ratio (MAX) =   0.0774526678141136"
# [1] "Walktrap ratio (AVG) =   0.0057985897422874"
# [1] "Infomap ratio (MAX) =  0.0558063192449733"
# [1] "Infomap ratio (AVG) =  0.0086533904081049"
# [1] "Number of circles =  3"
# [1] "Walktrap ratio (MAX) =   0.19131679389313"
# [1] "Walktrap ratio (AVG) =   0.00772257556397393"
# [1] "Infomap ratio (MAX) =  0.12346002621232"
# [1] "Infomap ratio (AVG) =  0.117605941459152"
# [1] "Number of circles =  5"
# [1] "Walktrap ratio (MAX) =   0.287037037037037"
# [1] "Walktrap ratio (AVG) =   0.0087731518730507"
# [1] "Infomap ratio (MAX) =  0.215419501133787"
# [1] "Infomap ratio (AVG) =  0.0233991504064323"
# [1] "Number of circles =  6"
# [1] "Walktrap ratio (MAX) =   0.270642201834862"
# [1] "Walktrap ratio (AVG) =   0.0210288531499438"
# [1] "Infomap ratio (MAX) =  0.5"
# [1] "Infomap ratio (AVG) =  0.0033047269428586"
# [1] "Number of circles =  3"
# [1] "Walktrap ratio (MAX) =   0.311538461538462"
# [1] "Walktrap ratio (AVG) =   0.0128815438277815"
# [1] "Infomap ratio (MAX) =  0.101655933762649"
# [1] "Infomap ratio (AVG) =  0.0109667622724702"
# [1] "Number of circles =  4"
# [1] "Walktrap ratio (MAX) =   0.375"
# [1] "Walktrap ratio (AVG) =   0.120689760727616"
# [1] "Infomap ratio (MAX) =  0.485436893203884"
# [1] "Infomap ratio (AVG) =  0.439320388349515"
# [1] "Number of circles =  4"
# [1] "Walktrap ratio (MAX) =   0.0454545454545455"
# [1] "Walktrap ratio (AVG) =   0.00267418945391617"
# [1] "Infomap ratio (MAX) =  0.037037037037037"
# [1] "Infomap ratio (AVG) =  0.000509345523484063"
# [1] "Number of circles =  14"
# [1] "Walktrap ratio (MAX) =   0.124463519313305"
# [1] "Walktrap ratio (AVG) =   0.035060324020901"
# [1] "Infomap ratio (MAX) =  0.0782122905027933"
# [1] "Infomap ratio (AVG) =  0.0121569753488796"
# [1] "Number of circles =  6"
# [1] "Walktrap ratio (MAX) =   0.0763430725730443"
# [1] "Walktrap ratio (AVG) =   0.00850097633760214"
# [1] "Infomap ratio (MAX) =  0.0524216524216524"
# [1] "Infomap ratio (AVG) =  0.00151551917088344"
# [1] "Number of circles =  10"
# [1] "Walktrap ratio (MAX) =   0.879194630872483"
# [1] "Walktrap ratio (AVG) =   0.128651450575066"
# [1] "Infomap ratio (MAX) =  0.860310421286031"
# [1] "Infomap ratio (AVG) =  0.160658869614997"
# [1] "Number of circles =  3"
# [1] "Walktrap ratio (MAX) =   0.347826086956522"
# [1] "Walktrap ratio (AVG) =   0.00548228055280356"
# [1] "Infomap ratio (MAX) =  0.0876552227903579"
# [1] "Infomap ratio (AVG) =  0.00125334608619255"
# [1] "Number of circles =  6"
# [1] "Walktrap ratio (MAX) =   0.652719665271967"
# [1] "Walktrap ratio (AVG) =   0.0540306165664859"
# [1] "Infomap ratio (MAX) =  0.379454926624738"
# [1] "Infomap ratio (AVG) =  0.195245288891238"
# [1] "Number of circles =  3"
# [1] "Walktrap ratio (MAX) =   0.364583333333333"
# [1] "Walktrap ratio (AVG) =   0.00858946221901945"
# [1] "Infomap ratio (MAX) =  0.287905604719764"
# [1] "Infomap ratio (AVG) =  0.0203013224962255"
# [1] "Number of circles =  4"
# [1] "Walktrap ratio (MAX) =   0.022883295194508"
# [1] "Walktrap ratio (AVG) =   0.000500243950409317"
# [1] "Infomap ratio (MAX) =  0.00715819613457409"
# [1] "Infomap ratio (AVG) =  5.28730396303768e-05"
# [1] "Number of circles =  4"
# [1] "Walktrap ratio (MAX) =   0.0176271186440678"
# [1] "Walktrap ratio (AVG) =   0.00041906246874881"
# [1] "Infomap ratio (MAX) =  0.380952380952381"
# [1] "Infomap ratio (AVG) =  0.00263503462956052"
# [1] "Number of circles =  10"
# [1] "Walktrap ratio (MAX) =   0.60377358490566"
# [1] "Walktrap ratio (AVG) =   0.00491098747495525"
# [1] "Infomap ratio (MAX) =  0.259803921568627"
# [1] "Infomap ratio (AVG) =  0.00587036255353005"
# [1] "Number of circles =  5"
# [1] "Walktrap ratio (MAX) =   0.707964601769911"
# [1] "Walktrap ratio (AVG) =   0.156568852890194"
# [1] "Infomap ratio (MAX) =  0.195509822263798"
# [1] "Infomap ratio (AVG) =  0.0193683373647276"
# [1] "Number of circles =  5"
# [1] "Walktrap ratio (MAX) =   0.152892561983471"
# [1] "Walktrap ratio (AVG) =   0.00580288017011779"
# [1] "Infomap ratio (MAX) =  0.0677146311970979"
# [1] "Infomap ratio (AVG) =  0.00310276931119076"
# [1] "Number of circles =  4"
# [1] "Walktrap ratio (MAX) =   0.5075"
# [1] "Walktrap ratio (AVG) =   0.0181438293782034"
# [1] "Infomap ratio (MAX) =  0.234194612424409"
# [1] "Infomap ratio (AVG) =  0.00424429775034391"
# [1] "Number of circles =  24"
# [1] "Walktrap ratio (MAX) =   0.872844827586207"
# [1] "Walktrap ratio (AVG) =   0.0117254445137826"
# [1] "Infomap ratio (MAX) =  0.573033707865168"
# [1] "Infomap ratio (AVG) =  0.00295965550373789"
# [1] "Number of circles =  4"
# [1] "Walktrap ratio (MAX) =   0.463576158940397"
# [1] "Walktrap ratio (AVG) =   0.0223083314828059"
# [1] "Infomap ratio (MAX) =  0.386363636363636"
# [1] "Infomap ratio (AVG) =  0.0061079799702308"
# [1] "Number of circles =  3"
# [1] "Walktrap ratio (MAX) =   0.105679862306368"
# [1] "Walktrap ratio (AVG) =   0.00367679586483409"
# [1] "Infomap ratio (MAX) =  0.073715733701912"
# [1] "Infomap ratio (AVG) =  0.00813944559625278"
# [1] "Number of circles =  3"
# [1] "Walktrap ratio (MAX) =   0.470890410958904"
# [1] "Walktrap ratio (AVG) =   0.0403852624246702"
# [1] "Infomap ratio (MAX) =  0.245149911816578"
# [1] "Infomap ratio (AVG) =  0.00866775426809954"
# [1] "Number of circles =  3"
# [1] "Walktrap ratio (MAX) =   0.929078014184397"
# [1] "Walktrap ratio (AVG) =   0.236995837660712"
# [1] "Infomap ratio (MAX) =  0.516499282639885"
# [1] "Infomap ratio (AVG) =  0.0275800832137251"
# [1] "Number of circles =  6"
# [1] "Walktrap ratio (MAX) =   0.0981679917041134"
# [1] "Walktrap ratio (AVG) =   0.00113893489584332"
# [1] "Infomap ratio (MAX) =  0.0715676728334956"
# [1] "Infomap ratio (AVG) =  0.000810395780372476"
# [1] "Number of circles =  3"
# [1] "Walktrap ratio (MAX) =   0.268209083119109"
# [1] "Walktrap ratio (AVG) =   0.0891212388249533"
# [1] "Infomap ratio (MAX) =  0.171841541755889"
# [1] "Infomap ratio (AVG) =  0.0170790900422899"
# [1] "Number of circles =  3"
# [1] "Walktrap ratio (MAX) =   0.478571428571429"
# [1] "Walktrap ratio (AVG) =   0.0676417086943403"
# [1] "Infomap ratio (MAX) =  0.21580547112462"
# [1] "Infomap ratio (AVG) =  0.0516717325227964"
# [1] "Number of circles =  5"
# [1] "Walktrap ratio (MAX) =   0.423404255319149"
# [1] "Walktrap ratio (AVG) =   0.0445520723475901"
# [1] "Infomap ratio (MAX) =  0.56"
# [1] "Infomap ratio (AVG) =  0.0313651461722284"
# [1] "Number of circles =  3"
# [1] "Walktrap ratio (MAX) =   0.142857142857143"
# [1] "Walktrap ratio (AVG) =   0.00671550671550672"
# [1] "Infomap ratio (MAX) =  0.0102040816326531"
# [1] "Infomap ratio (AVG) =  0.0102040816326531"
# [1] "Number of circles =  5"
# [1] "Walktrap ratio (MAX) =   0.192702394526796"
# [1] "Walktrap ratio (AVG) =   0.00533655485157513"
# [1] "Infomap ratio (MAX) =  0.128088426527958"
# [1] "Infomap ratio (AVG) =  0.0149869960988296"
# [1] "Number of circles =  5"
# [1] "Walktrap ratio (MAX) =   0.140692640692641"
# [1] "Walktrap ratio (AVG) =   0.00119265117732361"
# [1] "Infomap ratio (MAX) =  0.068561455996011"
# [1] "Infomap ratio (AVG) =  0.00200090226698868"
# [1] "Number of circles =  15"
# [1] "Walktrap ratio (MAX) =   0.454172366621067"
# [1] "Walktrap ratio (AVG) =   0.00514606700507339"
# [1] "Infomap ratio (MAX) =  0.0992414664981037"
# [1] "Infomap ratio (AVG) =  0.00222734849287666"
# [1] "Number of circles =  3"
# [1] "Walktrap ratio (MAX) =   0.305882352941176"
# [1] "Walktrap ratio (AVG) =   0.0172846418397183"
# [1] "Infomap ratio (MAX) =  0.153526970954357"
# [1] "Infomap ratio (AVG) =  0.0282312491297214"
# [1] "Number of circles =  3"
# [1] "Walktrap ratio (MAX) =   0.328621908127208"
# [1] "Walktrap ratio (AVG) =   0.0139982018429107"
# [1] "Infomap ratio (MAX) =  0.146862483311081"
# [1] "Infomap ratio (AVG) =  0.00854026585612299"
# [1] "Number of circles =  8"
# [1] "Walktrap ratio (MAX) =   0.822064056939502"
# [1] "Walktrap ratio (AVG) =   0.0409296003337261"
# [1] "Infomap ratio (MAX) =  0.3125"
# [1] "Infomap ratio (AVG) =  0.0141798219779392"
# [1] "Number of circles =  3"
# [1] "Walktrap ratio (MAX) =   0.220472440944882"
# [1] "Walktrap ratio (AVG) =   0.00808934420739287"
# [1] "Infomap ratio (MAX) =  0.0299363057324841"
# [1] "Infomap ratio (AVG) =  0.00467519882806507"
# [1] "Number of circles =  7"
# [1] "Walktrap ratio (MAX) =   0.5"
# [1] "Walktrap ratio (AVG) =   0.00684356198215984"
# [1] "Infomap ratio (MAX) =  0.125874125874126"
# [1] "Infomap ratio (AVG) =  0.00837633394986265"
# [1] "Number of circles =  3"
# [1] "Walktrap ratio (MAX) =   0.389312977099237"
# [1] "Walktrap ratio (AVG) =   0.0139916689376272"
# [1] "Infomap ratio (MAX) =  0.118015665796345"
# [1] "Infomap ratio (AVG) =  0.00193914939676357"
# [1] "Number of circles =  7"
# [1] "Walktrap ratio (MAX) =   0.104529616724739"
# [1] "Walktrap ratio (AVG) =   0.00175725374331607"
# [1] "Infomap ratio (MAX) =  0.0829457364341085"
# [1] "Infomap ratio (AVG) =  0.0022000738279808"
# [1] "Number of circles =  6"
# [1] "Walktrap ratio (MAX) =   1"
# [1] "Walktrap ratio (AVG) =   0.001953125"
# [1] "Infomap ratio (MAX) =  0.0256410256410256"
# [1] "Infomap ratio (AVG) =  0.00493096646942801"
# [1] "Number of circles =  3"
# [1] "Walktrap ratio (MAX) =   0.720306513409962"
# [1] "Walktrap ratio (AVG) =   0.00228249246019755"
# [1] "Infomap ratio (MAX) =  0.233766233766234"
# [1] "Infomap ratio (AVG) =  0.00151373387497921"
# [1] "Number of circles =  31"
# [1] "Walktrap ratio (MAX) =   0.884169884169884"
# [1] "Walktrap ratio (AVG) =   0.0528762778829615"
# [1] "Infomap ratio (MAX) =  0.69140625"
# [1] "Infomap ratio (AVG) =  0.0218773351039018"
# [1] "Number of circles =  3"
# [1] "Walktrap ratio (MAX) =   0.00743494423791822"
# [1] "Walktrap ratio (AVG) =   3.99178960627279e-05"
# [1] "Infomap ratio (MAX) =  0.00255536626916525"
# [1] "Infomap ratio (AVG) =  0.000851788756388416"
# [1] "Number of circles =  3"
# [1] "Walktrap ratio (MAX) =   0.0368098159509202"
# [1] "Walktrap ratio (AVG) =   0.0105299419854832"
# [1] "Infomap ratio (MAX) =  0.0195758564437194"
# [1] "Infomap ratio (AVG) =  0.00258292550299076"
# [1] "Number of circles =  3"
# [1] "Walktrap ratio (MAX) =   0.214912280701754"
# [1] "Walktrap ratio (AVG) =   0.00348531584610606"
# [1] "Infomap ratio (MAX) =  0.12314581584103"
# [1] "Infomap ratio (AVG) =  0.00214478665437598"
# [1] "Number of circles =  3"
# [1] "Walktrap ratio (MAX) =   0.0262172284644195"
# [1] "Walktrap ratio (AVG) =   0.00279289248946622"
# [1] "Infomap ratio (MAX) =  0.0183783783783784"
# [1] "Infomap ratio (AVG) =  0.000170168654720601"
# [1] "Number of circles =  4"
# [1] "Walktrap ratio (MAX) =   0.130970724191063"
# [1] "Walktrap ratio (AVG) =   0.0027210548189502"
# [1] "Infomap ratio (MAX) =  0.0325358851674641"
# [1] "Infomap ratio (AVG) =  0.000714724893269156"
# [1] "Number of circles =  4"
# [1] "Walktrap ratio (MAX) =   0.714285714285714"
# [1] "Walktrap ratio (AVG) =   0.0494897746689352"
# [1] "Infomap ratio (MAX) =  0.833333333333333"
# [1] "Infomap ratio (AVG) =  0.0404363021187896"
# [1] "Number of circles =  3"
# [1] "Walktrap ratio (MAX) =   0.110236220472441"
# [1] "Walktrap ratio (AVG) =   0.00517520727878989"
# [1] "Infomap ratio (MAX) =  0.0578231292517007"
# [1] "Infomap ratio (AVG) =  0.00547996976568405"
# [1] "Number of circles =  8"
# [1] "Walktrap ratio (MAX) =   0.103743315508021"
# [1] "Walktrap ratio (AVG) =   0.0142986297679303"
# [1] "Infomap ratio (MAX) =  0.0708092485549133"
# [1] "Infomap ratio (AVG) =  0.00558692816136776"
# [1] "Number of circles =  5"
# [1] "Walktrap ratio (MAX) =   0.022703818369453"
# [1] "Walktrap ratio (AVG) =   0.000442343687784738"
# [1] "Infomap ratio (MAX) =  0.0190318576748035"
# [1] "Infomap ratio (AVG) =  0.000114769280510293"
# [1] "Number of circles =  5"
# [1] "Walktrap ratio (MAX) =   0.374800637958533"
# [1] "Walktrap ratio (AVG) =   0.0252493073169708"
# [1] "Infomap ratio (MAX) =  0.207797772065124"
# [1] "Infomap ratio (AVG) =  0.00363126328371389"
# [1] "Number of circles =  12"
# [1] "Walktrap ratio (MAX) =   0.413223140495868"
# [1] "Walktrap ratio (AVG) =   0.0632078359351087"
# [1] "Infomap ratio (MAX) =  0.383098591549296"
# [1] "Infomap ratio (AVG) =  0.0379561576058211"

# %%
egoNodes
# Out:
#   [1] "100129275726588145876.circles" "100329698645326486178.circles"
#   [3] "100466178325794757407.circles" "100500197140377336562.circles"
#   [5] "100518419853963396365.circles" "100521671383026672718.circles"
#   [7] "100535338638690515335.circles" "100637660947564674695.circles"
#   [9] "100668989009254813743.circles" "100715738096376666180.circles"
#  [11] "100720409235366385249.circles" "100962871525684315897.circles"
#  [13] "101130571432010257170.circles" "101133961721621664586.circles"
#  [15] "101185748996927059931.circles" "101263615503715477581.circles"
#  [17] "101373961279443806744.circles" "101499880233887429402.circles"
#  [19] "101541879642294398860.circles" "101560853443212199687.circles"
#  [21] "101626577406833098387.circles" "101848191156408080085.circles"
#  [23] "101997124338642780860.circles" "102170431816592344972.circles"
#  [25] "102340116189726655233.circles" "102615863344410467759.circles"
#  [27] "102778563580121606331.circles" "103236949470535942612.circles"
#  [29] "103241736833663734962.circles" "103251633033550231172.circles"
#  [31] "103338524411980406972.circles" "103503116383846951534.circles"
#  [33] "103537112468125883734.circles" "103752943025677384806.circles"
#  [35] "103892332449873403244.circles" "104076158580173410325.circles"
#  [37] "104105354262797387583.circles" "104226133029319075907.circles"
#  [39] "104290609881668164623.circles" "104607825525972194062.circles"
#  [41] "104672614700283598130.circles" "104905626100400792399.circles"
#  [43] "104917160754181459072.circles" "104987932455782713675.circles"
#  [45] "105565257978663183206.circles" "105646458226420473639.circles"
#  [47] "106186407539128840569.circles" "106228758905254036967.circles"
#  [49] "106328207304735502636.circles" "106382433884876652170.circles"
#  [51] "106417861423111072106.circles" "106724181552911298818.circles"
#  [53] "106837574755355833243.circles" "107013688749125521109.circles"
#  [55] "107040353898400532534.circles" "107203023379915799071.circles"
#  [57] "107223200089245371832.circles" "107296660002634487593.circles"
#  [59] "107362628080904735459.circles" "107459220492917008623.circles"
#  [61] "107489144252174167638.circles" "107965826228461029730.circles"
#  [63] "108156134340151350951.circles" "108404515213153345305.circles"
#  [65] "108541235642523883716.circles" "108883879052307976051.circles"
#  [67] "109130886479781915270.circles" "109213135085178239952.circles"
#  [69] "109327480479767108490.circles" "109342148209917802565.circles"
#  [71] "109596373340495798827.circles" "109602109099036550366.circles"
#  [73] "110232479818136355682.circles" "110241952466097562819.circles"
#  [75] "110538600381916983600.circles" "110581012109008817546.circles"
#  [77] "110614416163543421878.circles" "110701307803962595019.circles"
#  [79] "110739220927723360152.circles" "110809308822849680310.circles"
#  [81] "110971010308065250763.circles" "111048918866742956374.circles"
#  [83] "111058843129764709244.circles" "111091089527727420853.circles"
#  [85] "111213696402662884531.circles" "111278293763545982455.circles"
#  [87] "112317819390625199896.circles" "112463391491520264813.circles"
#  [89] "112573107772208475213.circles" "112724573277710080670.circles"
#  [91] "112737356589974073749.circles" "112787435697866537461.circles"
#  [93] "113112256846010263985.circles" "113122049849685469495.circles"
#  [95] "113171096418029011322.circles" "113356364521839061717.circles"
#  [97] "113455290791279442483.circles" "113597493946570654755.circles"
#  [99] "113718775944980638561.circles" "113799277735885972934.circles"
# [101] "113881433443048137993.circles" "114054672576929802335.circles"
# [103] "114104634069486127920.circles" "114122960748905067938.circles"
# [105] "114124942936679476879.circles" "114147483140782280818.circles"
# [107] "114336431216099933033.circles" "115121555137256496805.circles"
# [109] "115273860520983542999.circles" "115360471097759949621.circles"
# [111] "115455024457484679647.circles" "115516333681138986628.circles"
# [113] "115573545440464933254.circles" "115576988435396060952.circles"
# [115] "115625564993990145546.circles" "116059998563577101552.circles"
# [117] "116247667398036716276.circles" "116315897040732668413.circles"
# [119] "116450966137824114154.circles" "116807883656585676940.circles"
# [121] "116825083494890429556.circles" "116899029375914044550.circles"
# [123] "116931379084245069738.circles" "117412175333096244275.circles"
# [125] "117503822947457399073.circles" "117668392750579292609.circles"
# [127] "117734260411963901771.circles" "117798157258572080176.circles"
# [129] "117866881767579360121.circles" "118107045405823607895.circles"
# [131] "118255645714452180374.circles" "118379821279745746467.circles"
